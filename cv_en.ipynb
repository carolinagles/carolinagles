# %% [markdown]
# ## María Carolina González Bernal
#
# ### Data Scientist
#
# #### +52 33 4583 0005 | Carolinagles@gmail.com | [GitHub](https://github.com/carolinagles) | Hermosillo, MX
#
# ---
#
# ### **Professional Profile**
#
# Anthropologist transitioning into data science, with a strong foundation in the analysis of human and cultural behaviors. Currently attending a data science bootcamp, where I apply tools such as Python, data visualization, statistical analysis, and machine learning. My interdisciplinary background allows me to enhance analysis projects, such as consumer profiling and social patterns, providing a multidisciplinary perspective to the decision-making process.
#
# ---
#
# ### **Technical Skills**
#
# Python (pandas, NumPy, matplotlib, seaborn, scikit-learn) | SQL | Statistical Analysis | Hypothesis Testing
#
# ---
#
# ### **Competencies**
#
# Attention to Detail | Critical Thinking | Self-discipline | Problem Solving | Continuous Learning | Time Management | Assertive Communication | Team Collaboration | Adaptability
#
# ---
#
# ### **Experience**
#
# **Public Administration Support**
# Hermosillo City Hall
# _February 2024 - October 2024_
#
# - Managed and organized large volumes of documentation related to public and private land processes, developing a systematic approach to optimize the process.
# - Proposed innovative solutions to reduce processing times, improving service quality through workflow analysis and improvement.
# - Experience in handling and structuring administrative data, transferring key skills to data science projects.
#
# **Public Administration and Teaching Support**
# Sonora Institute for the Care of Older Adults
# _January 2024_
#
# - Maintained and updated organizational databases, ensuring accuracy and consistency.
# - Classified critical information and generated reports, applying essential analytical skills.
# - Designed and taught educational courses, demonstrating the ability to simplify complex concepts, a skill useful for presenting data analysis findings.
#
# **Monitor for the Justice Plan for Indigenous Peoples**
# SEDESSON
# _June 2023 - September 2023_
#
# - Collected and analyzed qualitative and quantitative data from focus groups with Indigenous Peoples, providing key insights for public policy design.
# - Identified social patterns and specific needs of communities, developing measures to address them.
# - Applied data collection and analysis methodologies, fundamental to work in data science.
#
# ---
#
# ### **Projects**
#
# [Megaline - Smart vs Ultra](https://github.com/carolinagles/datascience/blob/main/8.Introduction_to_machine_learning/megaline_smart_ultra_en.ipynb)
# _November 2024_
#
# - Developed a classification model with at least 75% accuracy, capable of distinguishing between users of the Smart and Ultra plans.
# - Analyzed user consumption data to identify key characteristics of each plan.
# - By optimizing strategies, helped Megaline improve plan allocation, increase customer satisfaction, and maximize revenue.
#
#
# [Taxi Rides and Weather Impact in Chicago](https://github.com/carolinagles/datascience/blob/main/7.Data_%20collection_%20and_storage_(SQL)/taxis_en.ipynb) _November 2024_
#
# - Combined SQL analysis, data visualization, and statistical testing to generate valuable insights supporting strategic decision-making.
# - Identified key patterns in trips, such as the most popular companies and neighborhoods with the highest activity.
# - Analyzed the impact of weather on the frequency and duration of trips.
# - Proposed recommendations for Zuber to optimize operations and attract more passengers.
#
# [Video Games Success Prediction](https://github.com/carolinagles/datascience/blob/main/6.I_Python_and_Software_Engineering/games.ipynb) _October 2024_
#
# - Identified patterns that determine the success of video games to predict future game sales performance.
# - Identified promising projects to guide effective advertising strategies.
#
# ---
#
# ### **Education**
#
# **Data Science Bootcamp**
# TripleTen
# _July 2024 - Present_
#
# - Focus on data analysis, machine learning, and development of real-world projects.
# - Training in advanced tools such as Python, SQL, and data visualization.
# - Includes modules on statistics, hypotheses, and business metrics, and involves the completion of 12 projects based on real-world data.
#
# **Bachelor's in Anthropology**
# University of Sonora
# _October 2024_
#
# - Exchange student in the MA in Anthropology of the Americas
# University of Friedrich Wilhelm of Bonn | Winter Semester 2021
#
# ---
#
# ### **Other**
#
# - **Python for Data Science, AI & Development** | IBM by Coursera | July 2023
# - **Google Data Analytics** | Google by Coursera | July 2021
#
# ---
#
# ### **Languages**
#
# - English: Advanced
# - German: Basic
#
# ---
